# %%
import pandas as pd
import re
from sentence_transformers import SentenceTransformer, util
# Out:
# /Users/victorg/miniforge3/envs/rncp/lib/python3.10/site-packages/sentence_transformers/cross_encoder/CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %%
cleandf = pd.read_csv("cleangames.csv")

# %%
cleandf
# Out:
#             id  category  first_release_date  \
# 0       269473         0        1.696550e+09
# 1       264773         0        1.695773e+09
# 2       173172         3        1.632787e+09
# 3        46147         0        6.783264e+08
# 4       135341         0        1.544746e+09
# ...        ...       ...                 ...
# 248707     146         2        1.115251e+09
# 248708     110         0        7.258464e+08
# 248709      88         0        1.008288e+09
# 248710      48         0        1.245715e+09
# 248711      47         0        1.245715e+09
#
#                                             name                   platforms  \
# 0                                       Resonite                 [3, 6, 163]
# 1                               Lizards Must Die                         [6]
# 2             Outer Wilds: Archaeologist Edition  [6, 48, 49, 130, 167, 169]
# 3                             Golden Axe Warrior                        [64]
# 4                                        Adastra              [3, 6, 14, 34]
# ...                                          ...                         ...
# 248707  Star Wars Galaxies: Rage of the Wookiees                         [6]
# 248708       Freddy Pharkas: Frontier Pharmacist                 [6, 13, 14]
# 248709                      Frank Herbert's Dune                      [6, 8]
# 248710                         Overlord: Minions                        [20]
# 248711                     Overlord: Dark Legend                         [5]
#
#             rating                                      release_dates  \
# 0       100.000000                           [522725, 522726, 522727]
# 1        99.798620                                           [517965]
# 2        99.655340  [317893, 317894, 317895, 536374, 536745, 53674...
# 3        99.576263                                   [188124, 437283]
# 4        99.554056                   [376902, 376903, 376904, 376905]
# ...            ...                                                ...
# 248707         NaN                                           [124710]
# 248708         NaN                                    [298, 299, 300]
# 248709         NaN                              [31040, 31041, 31042]
# 248710         NaN                                              [792]
# 248711         NaN                              [791, 142019, 142020]
#
#                                            slug  \
# 0                                   resonite--1
# 1                              lizards-must-die
# 2             outer-wilds-archaeologist-edition
# 3                            golden-axe-warrior
# 4                                       adastra
# ...                                         ...
# 248707  star-wars-galaxies-rage-of-the-wookiees
# 248708       freddy-pharkas-frontier-pharmacist
# 248709                     frank-herbert-s-dune
# 248710                         overlord-minions
# 248711                     overlord-dark-legend
#
#                                                   summary       genres
# 0       enter a novel digital universe with infinite p...          NaN
# 1       the great exploits of the ancient rus in the w...     [25, 32]
# 2       outer wilds archaeologist edition contains out...  [9, 31, 32]
# 3       world peace is at stake death adder a wicked g...         [12]
# 4       after being kidnapped by a wolflike alien a ma...         [34]
# ...                                                   ...          ...
# 248707  star wars galaxies rage of the wookiees was th...         [12]
# 248708  the adventures of freddy pharkas a pharmacist ...      [2, 31]
# 248709  in the year the houses atreides and harkonnen ...      [9, 31]
# 248710  meet giblet blaze stench and zap an elite mini...      [9, 25]
# 248711  dark legend is a spinoff of the video game ove...     [25, 31]
#
# [248712 rows x 10 columns]

# %%
# Chargement du modèle Sentence Transformer
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')

# Chargement des données de jeux depuis cleangames.csv
games = cleandf[['name', 'summary']].to_dict('records')

# Encodage des descriptions de jeux
games_embeddings = model.encode([game['summary'] for game in games], convert_to_tensor=True)
# Out:
# /Users/victorg/miniforge3/envs/rncp/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
